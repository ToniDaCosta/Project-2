# %%
import os
import src.extracting as ext
import src.visualization as viz

# %%
df = ext.city_pop("https://worldpopulationreview.com/countries/cities/peru")

# %%
viz.counting_cities(df, "data/output_test.csv")
